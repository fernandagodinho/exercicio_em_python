# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandagodinho/exercicio_em_python/blob/main/tarefa_extra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt


cores_map = {
    'azul': 'blue',
    'amarelo': 'yellow',
    'vermelho': 'red',

}


cores_favoritas_traduzidas = [cores_map.get(cor.strip(), cor.strip()) for cor in cores_favoritas]

# Preparando dados para o gráfico
valores = [0.6, 0.8, 1]


plt.bar(cores_favoritas, valores, color=cores_favoritas_traduzidas)  # Gera o gráfico de barras
# Out:
# <BarContainer object of 3 artists>
